# %%
# !pip install mip
# Out:
# Collecting mip
#   Downloading mip-1.15.0-py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 49.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: cffi==1.15.* in /home/codespace/.local/lib/python3.10/site-packages (from mip) (1.15.1)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.10/site-packages (from cffi==1.15.*->mip) (2.21)
# Installing collected packages: mip
# Successfully installed mip-1.15.0

# %%
import pandas as pd

d = {'col1': [1, 2], 'col2': [3, 4]}
df = pd.DataFrame(data=d)
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
from itertools import product
from mip import Model, BINARY

n = m = 3

times = [[2, 1, 2],
         [1, 2, 2],
         [1, 2, 1]]

M = sum(times[i][j] for i in range(n) for j in range(m))

machines = [[2, 0, 1],
            [1, 2, 0],
            [2, 1, 0]]

model = Model('JSSP')

c = model.add_var(name="C")
x = [[model.add_var(name='x({},{})'.format(j+1, i+1))
      for i in range(m)] for j in range(n)]
y = [[[model.add_var(var_type=BINARY, name='y({},{},{})'.format(j+1, k+1, i+1))
       for i in range(m)] for k in range(n)] for j in range(n)]

model.objective = c

for (j, i) in product(range(n), range(1, m)):
    model += x[j][machines[j][i]] - x[j][machines[j][i-1]] >= \
        times[j][machines[j][i-1]]

for (j, k) in product(range(n), range(n)):
    if k != j:
        for i in range(m):
            model += x[j][i] - x[k][i] + M*y[j][k][i] >= times[k][i]
            model += -x[j][i] + x[k][i] - M*y[j][k][i] >= times[j][i] - M

for j in range(n):
    model += c - x[j][machines[j][m - 1]] >= times[j][machines[j][m - 1]]

model.optimize()

print("Completion time: ", c.x)
for (j, i) in product(range(n), range(m)):
    print("task %d starts on machine %d at time %g " % (j+1, i+1, x[j][i].x))
# Out:
# Welcome to the CBC MILP Solver
# Version: Trunk
# Build Date: Oct 24 2021
#
# Starting solution of the Linear programming relaxation problem using Dual Simplex
#
# Coin0506I Presolve 45 (0) rows, 28 (-9) columns and 126 (0) elements
# Clp0014I Perturbing problem by 0.001% of 1.3908042 - largest nonzero change 7.1258606e-05 ( 0.005123554%) - largest zero change 7.0163375e-05
# Clp0000I Optimal - objective value 5
# Coin0511I After Postsolve, objective 5, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 5 - 21 iterations time 0.002, Presolve 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 27 rows, 28 columns (18 integer (18 of which binary)) and 72 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 1.128%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty did not find any useful orbits in time 0
# Cbc0038I Initial state - 12 integers unsatisfied sum - 2.28571
# Cbc0038I Pass   1: suminf.    2.14286 (11) obj. 5 iterations 9
# Cbc0038I Pass   2: suminf.    0.35714 (2) obj. 16 iterations 24
# Cbc0038I Solution found of 16
# Cbc0038I Relaxing continuous gives 7
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 3 continuous
# Cbc0038I Full problem 27 rows 28 columns, reduced to 12 rows 11 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 6.79991
# Cbc0038I Pass   3: suminf.    2.14286 (11) obj. 5 iterations 0
# Cbc0038I Pass   4: suminf.    0.35714 (3) obj. 6.79991 iterations 22
# Cbc0038I Pass   5: suminf.    0.14286 (2) obj. 6.79991 iterations 7
# Cbc0038I Pass   6: suminf.    0.14286 (2) obj. 6.79991 iterations 4
# Cbc0038I Pass   7: suminf.    1.02858 (7) obj. 6.79991 iterations 12
# Cbc0038I Pass   8: suminf.    0.21429 (2) obj. 6.79991 iterations 15
# Cbc0038I Pass   9: suminf.    0.21429 (2) obj. 6.79991 iterations 6
# Cbc0038I Pass  10: suminf.    1.07143 (7) obj. 6.79991 iterations 12
# Cbc0038I Pass  11: suminf.    0.42857 (3) obj. 6.79991 iterations 14
# Cbc0038I Pass  12: suminf.    0.21429 (2) obj. 6.79991 iterations 8
# Cbc0038I Pass  13: suminf.    0.21429 (2) obj. 6.79991 iterations 7
# Cbc0038I Pass  14: suminf.    0.50000 (3) obj. 6.79991 iterations 2
# Cbc0038I Pass  15: suminf.    0.71429 (5) obj. 6.79991 iterations 4
# Cbc0038I Pass  16: suminf.    0.42857 (3) obj. 6.79991 iterations 10
# Cbc0038I Pass  17: suminf.    1.18573 (8) obj. 6.79991 iterations 11
# Cbc0038I Pass  18: suminf.    1.67144 (9) obj. 6.79991 iterations 1
# Cbc0038I Pass  19: suminf.    1.67144 (9) obj. 6.79991 iterations 0
# Cbc0038I Pass  20: suminf.    1.94286 (10) obj. 6.79991 iterations 2
# Cbc0038I Pass  21: suminf.    1.94286 (10) obj. 6.79991 iterations 0
# Cbc0038I Pass  22: suminf.    2.85714 (13) obj. 6.79991 iterations 9
# Cbc0038I Pass  23: suminf.    0.02858 (2) obj. 6.79991 iterations 18
# Cbc0038I Pass  24: suminf.    0.02858 (2) obj. 6.79991 iterations 8
# Cbc0038I Pass  25: suminf.    0.58572 (4) obj. 6.79991 iterations 5
# Cbc0038I Pass  26: suminf.    1.40002 (10) obj. 6.79991 iterations 9
# Cbc0038I Pass  27: suminf.    0.14286 (2) obj. 6.79991 iterations 20
# Cbc0038I Pass  28: suminf.    0.14286 (2) obj. 6.79991 iterations 5
# Cbc0038I Pass  29: suminf.    1.78571 (9) obj. 6 iterations 14
# Cbc0038I Pass  30: suminf.    0.35714 (4) obj. 6.79991 iterations 17
# Cbc0038I Pass  31: suminf.    0.35714 (3) obj. 6.79991 iterations 7
# Cbc0038I Pass  32: suminf.    2.00000 (10) obj. 6.79991 iterations 12
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 27 rows 28 columns, reduced to 27 rows 28 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of 7 - took 0.01 seconds
# Cbc0012I Integer solution of 7 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0038I Full problem 27 rows 28 columns, reduced to 27 rows 23 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0031I 4 added rows had average density of 2.25
# Cbc0013I At root node, 10 cuts changed objective from 5 to 7 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 48 row cuts average 3.0 elements, 6 column cuts (6 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 20 row cuts average 3.8 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 16 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 24 row cuts average 3.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 7, took 52 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Completion time:  7.0
# task 1 starts on machine 1 at time 2
# task 1 starts on machine 2 at time 5
# task 1 starts on machine 3 at time 0
# task 2 starts on machine 1 at time 5
# task 2 starts on machine 2 at time 0
# task 2 starts on machine 3 at time 3
# task 3 starts on machine 1 at time 6
# task 3 starts on machine 2 at time 3
# task 3 starts on machine 3 at time 2
